# %% [markdown]
# # Entrega Nro1 DataEngineer comision cincomil y pico
# Para esta entrega se utilizara la API de CoinGecko la cual utilizaremos para traer la cotización del token de preferencia del cual desee utilizar la person

# %% [markdown]
# ## Importamos librerias

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Definimos la URL base de la API de CoinGecko

# %%
base_url = "https://api.coingecko.com/api/v3"

# %% [markdown]
# Vamos a traer la información sobre las principales criptomonedas ordenadas por capitalización de mercado en dólares.

# %%
endpoint = "/coins/markets"
url = base_url + endpoint
parameters = {
    "vs_currency" : "usd"
}

try:
    response = requests.get(url, params = parameters)
    response.raise_for_status()  # Verificar si la solicitud fue exitosa
    data = response.json()
except requests.exceptions.RequestException as e:
    print(f"Error al realizar la solicitud:, {e}")

# %% [markdown]
# Si la consulta no levantó una excepcion, la trasformamos en un Dataframe para examinar que datos trajo

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                100 non-null    object
#  1   symbol                            100 non-null    object
#  2   name                              100 non-null    object
#  3   image                             100 non-null    object
#  4   current_price                     100 non-null    float64
#  5   market_cap                        100 non-null    int64
#  6   market_cap_rank                   100 non-null    int64
#  7   fully_diluted_valuation           94 non-null     float64
#  8   total_volume                      100 non-null    float64
#  9   high_24h                          100 non-null    float64
#  10  low_24h                           100 non-null    float64
#  11  price_change_24h                  100 non-null    float64
#  12  price_change_percentage_24h       100 non-null    float64
#  13  market_cap_change_24h             100 non-null    float64
#  14  market_cap_change_percentage_24h  100 non-null    float64
#  15  circulating_supply                100 non-null    float64
#  16  total_supply                      94 non-null     float64
#  17  max_supply                        58 non-null     float64
#  18  ath                               100 non-null    float64
#  19  ath_change_percentage             100 non-null    float64
#  20  ath_date                          100 non-null    object
#  21  atl                               100 non-null    float64
#  22  atl_change_percentage             100 non-null    float64
#  23  atl_date                          100 non-null    object
#  24  roi                               24 non-null     object
#  25  last_updated                      100 non-null    object
# dtypes: float64(16), int64(2), object(8)
# memory usage: 20.4+ KB

# %%
df.head(10)
# Out:
#              id symbol               name  \
# 0       bitcoin    btc            Bitcoin
# 1      ethereum    eth           Ethereum
# 2        tether   usdt             Tether
# 3   binancecoin    bnb                BNB
# 4      usd-coin   usdc           USD Coin
# 5        ripple    xrp                XRP
# 6  staked-ether  steth  Lido Staked Ether
# 7       cardano    ada            Cardano
# 8      dogecoin   doge           Dogecoin
# 9          tron    trx               TRON
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...   25849.000000
# 1  https://assets.coingecko.com/coins/images/279/...    1729.790000
# 2  https://assets.coingecko.com/coins/images/325/...       0.999701
# 3  https://assets.coingecko.com/coins/images/825/...     244.630000
# 4  https://assets.coingecko.com/coins/images/6319...       0.999232
# 5  https://assets.coingecko.com/coins/images/44/l...       0.500891
# 6  https://assets.coingecko.com/coins/images/1344...    1727.170000
# 7  https://assets.coingecko.com/coins/images/975/...       0.270765
# 8  https://assets.coingecko.com/coins/images/5/la...       0.061474
# 9  https://assets.coingecko.com/coins/images/1094...       0.072251
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  501574817308                1             5.428816e+11  8.460417e+09
# 1  207997277116                2             2.079973e+11  4.501701e+09
# 2   83532357924                3             8.347085e+10  1.286920e+10
# 3   38197158291                4             4.901621e+10  1.088559e+09
# 4   28050543428                5             2.804374e+10  1.863199e+09
# 5   26053714313                6             5.011581e+10  1.555641e+09
# 6   12429372566                7             1.242937e+10  4.695741e+06
# 7    9494313593                8             1.219129e+10  1.904180e+08
# 8    8596146937                9             8.596114e+09  1.786017e+08
# 9    6508660900               10             6.508690e+09  2.372782e+08
#
#        high_24h  ...  total_supply    max_supply           ath  \
# 0  26047.000000  ...  2.100000e+07  2.100000e+07  69045.000000
# 1   1749.650000  ...  1.202241e+08           NaN   4878.260000
# 2      1.002000  ...  8.349578e+10           NaN      1.320000
# 3    251.240000  ...  1.579002e+08  2.000000e+08    686.310000
# 4      1.002000  ...  2.805810e+10           NaN      1.170000
# 5      0.525823  ...  9.998888e+10  1.000000e+11      3.400000
# 6   1749.520000  ...  7.195666e+06  7.195666e+06   4829.570000
# 7      0.277159  ...  4.500000e+10  4.500000e+10      3.090000
# 8      0.062298  ...  1.397667e+11           NaN      0.731578
# 9      0.072846  ...  9.008056e+10           NaN      0.231673
#
#    ath_change_percentage                  ath_date         atl  \
# 0              -62.60812  2021-11-10T14:24:11.849Z   67.810000
# 1              -64.58458  2021-11-10T14:24:19.604Z    0.432979
# 2              -24.53680  2018-07-24T00:00:00.000Z    0.572521
# 3              -64.34068  2021-05-10T07:24:17.097Z    0.039818
# 4              -14.86703  2019-05-08T00:40:28.300Z    0.877647
# 5              -85.33860  2018-01-07T00:00:00.000Z    0.002686
# 6              -64.22694  2021-11-10T14:40:47.256Z  482.900000
# 7              -91.23687  2021-09-02T06:00:10.474Z    0.019253
# 8              -91.60828  2021-05-08T05:08:23.458Z    0.000087
# 9              -68.86441  2018-01-05T00:00:00.000Z    0.001804
#
#    atl_change_percentage                  atl_date  \
# 0            37973.31746  2013-07-06T00:00:00.000Z
# 1           398916.30352  2015-10-20T00:00:00.000Z
# 2               74.39535  2015-03-02T00:00:00.000Z
# 3           614531.93128  2017-10-19T00:00:00.000Z
# 4               13.75416  2023-03-11T08:02:13.981Z
# 5            18448.84461  2014-05-22T00:00:00.000Z
# 6              257.77568  2020-12-22T04:08:21.854Z
# 7             1305.04615  2020-03-13T02:22:55.044Z
# 8            70543.67136  2015-05-06T00:00:00.000Z
# 9             3897.72794  2017-11-12T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2023-06-14T18:34:38.622Z
# 1  {'times': 88.47266456354276, 'currency': 'btc'...  2023-06-14T18:34:41.711Z
# 2                                               None  2023-06-14T18:30:00.376Z
# 3                                               None  2023-06-14T18:34:38.009Z
# 4                                               None  2023-06-14T18:34:41.914Z
# 5                                               None  2023-06-14T18:34:38.710Z
# 6                                               None  2023-06-14T18:34:23.335Z
# 7                                               None  2023-06-14T18:34:36.428Z
# 8                                               None  2023-06-14T18:34:43.393Z
# 9  {'times': 37.027006404200236, 'currency': 'usd...  2023-06-14T18:34:36.534Z
#
# [10 rows x 26 columns]

# %% [markdown]
# Transformamos los datos y nos quedaremos con las columnas más relevantes

# %%
selected_columns = [
    'id', 
    'symbol', 
    'name', 
    'current_price', 
    'market_cap', 
    'market_cap_rank', 
    'total_volume', 
    'high_24h',
    'low_24h',
    'price_change_24h',
    'price_change_percentage_24h',
    'market_cap_change_24h',
    'market_cap_change_percentage_24h',
    'circulating_supply',
    'ath',
    'ath_change_percentage',
    'ath_date',
    'atl',
    'atl_change_percentage',
    'atl_date',
    'last_updated',
]

df_coins = df.loc[:, selected_columns]

# %% [markdown]
# Guardamos los datos

# %%
df_coins.to_json('./DB/coins.json')

# %% [markdown]
# Volvemos a traer la información para generar la tabla

# %%
df_coins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                100 non-null    object
#  1   symbol                            100 non-null    object
#  2   name                              100 non-null    object
#  3   current_price                     100 non-null    float64
#  4   market_cap                        100 non-null    int64
#  5   market_cap_rank                   100 non-null    int64
#  6   total_volume                      100 non-null    float64
#  7   high_24h                          100 non-null    float64
#  8   low_24h                           100 non-null    float64
#  9   price_change_24h                  100 non-null    float64
#  10  price_change_percentage_24h       100 non-null    float64
#  11  market_cap_change_24h             100 non-null    float64
#  12  market_cap_change_percentage_24h  100 non-null    float64
#  13  circulating_supply                100 non-null    float64
#  14  ath                               100 non-null    float64
#  15  ath_change_percentage             100 non-null    float64
#  16  ath_date                          100 non-null    object
#  17  atl                               100 non-null    float64
#  18  atl_change_percentage             100 non-null    float64
#  19  atl_date                          100 non-null    object
#  20  last_updated                      100 non-null    object
# dtypes: float64(13), int64(2), object(6)
# memory usage: 16.5+ KB

# %%
print(df_coins)
# Out:
#                     id symbol          name  current_price    market_cap  \
# 0              bitcoin    btc       Bitcoin   25849.000000  501574817308
# 1             ethereum    eth      Ethereum    1729.790000  207997277116
# 2               tether   usdt        Tether       0.999701   83532357924
# 3          binancecoin    bnb           BNB     244.630000   38197158291
# 4             usd-coin   usdc      USD Coin       0.999232   28050543428
# ..                 ...    ...           ...            ...           ...
# 95              chiliz    chz        Chiliz       0.067556     361504413
# 96          frax-share    fxs    Frax Share       4.990000     361420023
# 97  trust-wallet-token    twt  Trust Wallet       0.855986     358230859
# 98                 sui    sui           Sui       0.670880     354614616
# 99                nexo   nexo          NEXO       0.619378     346906534
#
#     market_cap_rank  total_volume      high_24h       low_24h  \
# 0                 1  8.460417e+09  26047.000000  25792.000000
# 1                 2  4.501701e+09   1749.650000   1727.230000
# 2                 3  1.286920e+10      1.002000      0.997417
# 3                 4  1.088559e+09    251.240000    237.060000
# 4                 5  1.863199e+09      1.002000      0.996778
# ..              ...           ...           ...           ...
# 95               97  2.423168e+07      0.068299      0.067166
# 96               96  4.673247e+06      5.050000      4.950000
# 97               99  4.621103e+07      0.883163      0.736329
# 98               98  1.592689e+08      0.717013      0.663621
# 99              100  3.334789e+06      0.623799      0.610264
#
#     price_change_24h  ...  market_cap_change_24h  \
# 0         -42.477570  ...          -7.242643e+08
# 1         -12.845472  ...          -1.575035e+09
# 2          -0.000128  ...           3.661355e+07
# 3           6.280000  ...           1.036022e+09
# 4          -0.000605  ...          -1.757149e+08
# ..               ...  ...                    ...
# 95          0.000191  ...           2.168232e+06
# 96          0.031058  ...           2.193589e+06
# 97          0.119542  ...           5.149749e+07
# 98         -0.015673  ...          -8.428842e+06
# 99         -0.003283  ...          -1.225808e+06
#
#     market_cap_change_percentage_24h  circulating_supply           ath  \
# 0                           -0.14419        1.940215e+07  69045.000000
# 1                           -0.75155        1.202241e+08   4878.260000
# 2                            0.04385        8.355731e+10      1.320000
# 3                            2.78792        1.558552e+08    686.310000
# 4                           -0.62252        2.806490e+10      1.170000
# ..                               ...                 ...           ...
# 95                           0.60340        5.344065e+09      0.878633
# 96                           0.61064        7.239512e+07     42.800000
# 97                          16.78901        4.166499e+08      2.720000
# 98                          -2.32172        5.282737e+08      2.160000
# 99                          -0.35211        5.600000e+08      4.070000
#
#     ath_change_percentage                  ath_date        atl  \
# 0               -62.60812  2021-11-10T14:24:11.849Z  67.810000
# 1               -64.58458  2021-11-10T14:24:19.604Z   0.432979
# 2               -24.53680  2018-07-24T00:00:00.000Z   0.572521
# 3               -64.34068  2021-05-10T07:24:17.097Z   0.039818
# 4               -14.86703  2019-05-08T00:40:28.300Z   0.877647
# ..                    ...                       ...        ...
# 95              -92.30807  2021-03-13T08:04:21.200Z   0.004109
# 96              -88.33408  2022-01-12T15:22:27.465Z   1.500000
# 97              -68.91825  2022-12-11T23:25:46.205Z   0.002776
# 98              -69.31255  2023-05-03T12:00:26.430Z   0.557963
# 99              -84.91059  2021-05-12T14:37:47.535Z   0.045153
#
#     atl_change_percentage                  atl_date              last_updated
# 0             37973.31746  2013-07-06T00:00:00.000Z  2023-06-14T18:34:38.622Z
# 1            398916.30352  2015-10-20T00:00:00.000Z  2023-06-14T18:34:41.711Z
# 2                74.39535  2015-03-02T00:00:00.000Z  2023-06-14T18:30:00.376Z
# 3            614531.93128  2017-10-19T00:00:00.000Z  2023-06-14T18:34:38.009Z
# 4                13.75416  2023-03-11T08:02:13.981Z  2023-06-14T18:34:41.914Z
# ..                    ...                       ...                       ...
# 95             1544.82621  2019-09-28T00:00:00.000Z  2023-06-14T18:34:40.873Z
# 96              232.16593  2021-06-25T16:50:51.447Z  2023-06-14T18:34:36.554Z
# 97            30360.40050  2020-06-09T09:15:06.983Z  2023-06-14T18:34:45.862Z
# 98               18.93646  2023-06-10T06:00:47.648Z  2023-06-14T18:34:43.064Z
# 99             1259.45814  2018-09-13T00:00:00.000Z  2023-06-14T18:34:41.185Z
#
# [100 rows x 21 columns]
